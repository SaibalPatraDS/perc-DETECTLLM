# %%
# %%capture
# !pip install fastparquet

# %% [markdown]
# ## Loading the dataset
# ------------------

# %%
## reading the existing data

## loading the data

import pandas as pd

final_data = pd.read_parquet("/content/drive/MyDrive/BTP 8th SEM/Data/Dataset/DetectLLM.parquet", engine = 'fastparquet')
final_data.shape
# Out:
# (518250, 2)

# %% [markdown]
# ## Saving to the CSV file
# ---------------------------

# %%
final_data.to_csv("/content/drive/MyDrive/BTP 8th SEM/Data/Dataset/DetectLLM.csv", index = False)
