# %% [markdown]
# # Dataset download from `huggingface`
# -----------------------------------------------

# %%
# !pip install datasets

# %%
from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")

# %%
dataset

# %%
# train_dataset = dataset['train']
# # train_dataset[0]
# # len(train_dataset)
# train_dataset.get('label')

# %%
# import pandas as pd
# from datasets import load_dataset

# def read_dataset_dict(dataset_dict):
#     # Initialize an empty DataFrame
#     df = pd.DataFrame(columns=['id', 'text', 'label', 'src'])

#     # Initialize id counter
#     id_counter = 1

#     # Iterate over each dataset in the DatasetDict
#     for dataset_name, dataset in dataset_dict.items():
#         # Read the data from the current dataset
#         data = dataset[:]

#         # Assign ids starting from id_counter
#         data['id'] = range(id_counter, id_counter + len(data))

#         # Update id_counter
#         id_counter += len(data)

#         # Append the data to the DataFrame
#         df = df.append(data, ignore_index=True)

#     return df

# # Load your DatasetDict (replace 'your_dataset_name' with the actual name of your dataset)
# dataset_dict = load_dataset("yaful/DeepfakeTextDetect")

# # Create the DataFrame
# df = read_dataset_dict(dataset_dict)

# # Display the DataFrame
# print(df)
